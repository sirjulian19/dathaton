# %% [markdown]
# IMPORTING DATA

# %%
import pandas as pd
df_demographics=pd.read_csv('dathaton/Dataset/demographics.csv')
df_geographic=pd.read_csv('dathaton/Dataset/geographic.csv')
df_green_trips_new_2=pd.read_csv('dathaton/Dataset/green_trips_new_2.csv')
df_mta_trips=pd.read_csv('dathaton/Dataset/mta_trips.csv')
df_uber_trips_2014=pd.read_csv('dathaton/Dataset/uber_trips_2014.csv')
df_uber_trips_2015=pd.read_csv('dathaton/Dataset/uber_trips_2015.csv')
df_weather=pd.read_csv('dathaton/Dataset/weather.csv')
df_yellow_trips=pd.read_csv('dathaton/Dataset/yellow_trips_new.csv')
df_zones=pd.read_csv('dathaton/Dataset/zones.csv')
# Out:
# C:\Users\mtkanalistadatos\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# DATA DEMOGRAPHICS

# %%
print(df_demographics.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 33 columns):
# nta_name            188 non-null object
# borough             188 non-null object
# nta_code            188 non-null object
# population          188 non-null int64
# under_5_years       188 non-null int64
# 5-9_years           188 non-null int64
# 10-14_years         188 non-null int64
# 15-19_years         188 non-null int64
# 20-24_years         188 non-null int64
# 25-29_years         188 non-null int64
# 30-34_years         188 non-null int64
# 35-39_years         188 non-null int64
# 40-44_years         188 non-null int64
# 45-49_years         188 non-null int64
# 50-54_years         188 non-null int64
# 55-59_years         188 non-null int64
# 60-64_years         188 non-null int64
# over_65_years       188 non-null int64
# median_age          188 non-null int64
# people_per_acre     188 non-null float64
# households          188 non-null int64
# ...

# %%
print(df_demographics.describe())
# Out:
#           population  under_5_years     5-9_years   10-14_years  15-19_years  \
# count     188.000000      188.00000    188.000000    188.000000   188.000000
# mean    43397.175532     2752.12766   2515.478723   2489.159574  2842.632979
# std     21288.062949     1695.80947   1496.808314   1459.440306  1574.371410
# min     13354.000000      506.00000    408.000000    326.000000   449.000000
# 25%     27237.000000     1490.50000   1443.500000   1437.750000  1619.000000
# 50%     37897.000000     2386.00000   2228.500000   2197.500000  2568.000000
# 75%     54244.750000     3579.25000   3242.750000   3263.750000  3717.250000
# max    132378.000000    14703.00000  11971.000000  10024.000000  9094.000000
#
#         20-24_years   25-29_years   30-34_years   35-39_years   40-44_years  \
# count    188.000000    188.000000    188.000000    188.000000    188.000000
# mean    3404.617021   3872.106383   3512.468085   3116.265957   3007.898936
# ...

# %% [markdown]
# The following code show the total missing values for each column of demographics

# %%
print("null values demographics: \n ")
print(df_demographics.isna().sum())
# Out:
# null values demographics:
#
# nta_name            0
# borough             0
# nta_code            0
# population          0
# under_5_years       0
# 5-9_years           0
# 10-14_years         0
# 15-19_years         0
# 20-24_years         0
# 25-29_years         0
# 30-34_years         0
# 35-39_years         0
# 40-44_years         0
# 45-49_years         0
# 50-54_years         0
# 55-59_years         0
# 60-64_years         0
# over_65_years       0
# median_age          0
# people_per_acre     0
# households          0
# less_than_10,000    0
# 10000_to_14999      0
# 15000_to_24999      0
# 25000_to_34999      0
# 35000_to_49999      0
# 50000_to_74999      0
# 75000_to_99999      0
# 100000_to_149999    0
# 150000_to_199999    0
# 200000_or_more      0
# median_income       0
# mean_income         0
# dtype: int64

# %% [markdown]
# OUTLIERS IN DEMOGRAPHICS

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df_demographics['population'], color='lime')
plt.xlabel('Population', fontsize=14)
plt.show()

# %%
sns.boxplot(x=df_demographics['median_age'], color='lime')
plt.xlabel('median_age', fontsize=14)
plt.show()

# %%
sns.boxplot(x=df_demographics['people_per_acre'], color='lime')
plt.xlabel('people_per_acre', fontsize=14)
plt.show()

# %%
sns.boxplot(x=df_demographics['households'], color='lime')
plt.xlabel('households', fontsize=14)
plt.show()

# %%
sns.boxplot(x=df_demographics['median_income'], color='lime')
plt.xlabel('median_income', fontsize=14)
plt.show()

# %%
sns.boxplot(x=df_demographics['mean_income'], color='lime')
plt.xlabel('mean_income', fontsize=14)
plt.show()

# %%
df_demographics_plot=df_demographics[['population','median_age','people_per_acre','households',
                                                    'median_income','mean_income']]
x=sns.PairGrid(df_demographics_plot)
x=x.map_diag(plt.hist)
x=x.map_offdiag(plt.scatter)

# %% [markdown]
# DATA GREEN TRIPS

# %%
print(df_green_trips_new_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589048 entries, 0 to 3589047
# Data columns (total 9 columns):
# pickup_datetime      object
# dropoff_datetime     object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count      int64
# trip_distance        float64
# total_amount         float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 246.4+ MB
# None

# %%
print(df_green_trips_new_2.describe())
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count      3.589048e+06     3.589048e+06       3.589048e+06      3.589048e+06
# mean      -7.381415e+01     4.068699e+01      -7.382658e+01      4.069179e+01
# std        2.976375e+00     1.641374e+00       2.812674e+00      1.550998e+00
# min       -1.223996e+02     0.000000e+00      -1.223996e+02      0.000000e+00
# 25%       -7.395853e+01     4.070282e+01      -7.396718e+01      4.070625e+01
# 50%       -7.394424e+01     4.074771e+01      -7.394400e+01      4.075044e+01
# 75%       -7.391512e+01     4.080492e+01      -7.390833e+01      4.079577e+01
# max        0.000000e+00     4.278692e+01       0.000000e+00      4.316054e+01
#
#        passenger_count  trip_distance  total_amount
# count     3.589048e+06   3.589048e+06  3.589048e+06
# mean      1.404419e+00   2.949620e+00  1.478221e+01
# std       1.094672e+00   2.980152e+00  2.977614e+01
# min       0.000000e+00   0.000000e+00 -3.500000e+02
# ...

# %% [markdown]
# The following code show the total missing values for each column of green trips

# %%
print("null values green trips: \n ")
print(df_green_trips_new_2.isna().sum())
# Out:
# null values green trips:
#
# pickup_datetime      0
# dropoff_datetime     0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# trip_distance        0
# total_amount         0
# dtype: int64

# %% [markdown]
# OUTLIERS IN DEMOGRAPHICS

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_green_trips_new_2['pickup_longitude'], color='black')
plt.xlabel('pickup_longitude', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_green_trips_new_2['pickup_latitude'], color='black')
plt.xlabel('pickup_latitude', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_green_trips_new_2['dropoff_longitude'], color='black')
plt.xlabel('dropoff_longitude', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_green_trips_new_2['dropoff_latitude'], color='black')
plt.xlabel('dropoff_latitude', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_green_trips_new_2['passenger_count'], color='black')
plt.xlabel('passenger_count', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_green_trips_new_2['trip_distance'], color='black')
plt.xlabel('trip_distance', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_green_trips_new_2['total_amount'], color='black')
plt.xlabel('total_amount', fontsize=14)
plt.show()

# %% [markdown]
# DATA MTA TRIPS

# %%
print(df_mta_trips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7554197 entries, 0 to 7554196
# Data columns (total 10 columns):
# station        object
# line_name      object
# division       object
# audit_type     object
# unit_id        object
# datetime       object
# new_entries    int64
# new_exits      int64
# latitude       float64
# longitude      float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 576.3+ MB
# None

# %%
print(df_mta_trips.describe())
# Out:
#         new_entries     new_exits      latitude     longitude
# count  7.554197e+06  7.554197e+06  7.554197e+06  7.554197e+06
# mean   2.129277e+02  1.599114e+02  4.072606e+01 -7.394976e+01
# std    2.493005e+02  2.134589e+02  6.815059e-02  5.788395e-02
# min    1.000000e+00  1.000000e+00  4.057613e+01 -7.402840e+01
# 25%    3.500000e+01  2.600000e+01  4.068436e+01 -7.399336e+01
# 50%    1.230000e+02  8.000000e+01  4.072530e+01 -7.396850e+01
# 75%    2.970000e+02  2.050000e+02  4.075680e+01 -7.391656e+01
# max    1.566000e+03  1.566000e+03  4.090313e+01 -7.375541e+01

# %% [markdown]
# The following code show the total missing values for each column of mta trips

# %%
print("null values mta trips: \n ")
print(df_mta_trips.isna().sum())
# Out:
# null values mta trips:
#
# station        0
# line_name      0
# division       0
# audit_type     0
# unit_id        0
# datetime       0
# new_entries    0
# new_exits      0
# latitude       0
# longitude      0
# dtype: int64

# %% [markdown]
# OUTLIERS IN MTA TRIPS

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_mta_trips['new_entries'], color='black')
plt.xlabel('new_entries', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_mta_trips['new_exits'], color='black')
plt.xlabel('new_exits', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_mta_trips['latitude'], color='black')
plt.xlabel('latitude', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_mta_trips['longitude'], color='black')
plt.xlabel('longitude', fontsize=14)
plt.show()

# %% [markdown]
# DATA UBER TRIPS 2014

# %%
print(df_uber_trips_2014.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4534327 entries, 0 to 4534326
# Data columns (total 4 columns):
# pickup_datetime     object
# pickup_latitude     float64
# pickup_longitude    float64
# base                object
# dtypes: float64(2), object(2)
# memory usage: 138.4+ MB
# None

# %%
print(df_uber_trips_2014.describe())
# Out:
#        pickup_latitude  pickup_longitude
# count     4.534327e+06      4.534327e+06
# mean      4.073926e+01     -7.397302e+01
# std       3.994991e-02      5.726670e-02
# min       3.965690e+01     -7.492900e+01
# 25%       4.072110e+01     -7.399650e+01
# 50%       4.074220e+01     -7.398340e+01
# 75%       4.076100e+01     -7.396530e+01
# max       4.211660e+01     -7.206660e+01

# %% [markdown]
# The following code show the total missing values for each column of uber trips 2014

# %%
print("null values uber trips 2014: \n ")
print(df_uber_trips_2014.isna().sum())
# Out:
# null values uber trips 2014:
#
# pickup_datetime     0
# pickup_latitude     0
# pickup_longitude    0
# base                0
# dtype: int64

# %% [markdown]
# OUTLIERS IN UBER TRIPS 2014

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_uber_trips_2014['pickup_latitude'], color='black')
plt.xlabel('pickup_latitude', fontsize=14)
plt.show()

# %% [markdown]
# DATA UBER TRIPS 2015

# %%
print(df_uber_trips_2015.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14270479 entries, 0 to 14270478
# Data columns (total 4 columns):
# pickup_datetime       object
# pickup_location_id    int64
# dispatch_base         object
# affiliate_base        object
# dtypes: int64(1), object(3)
# memory usage: 435.5+ MB
# None

# %%
print(df_uber_trips_2015.describe())
# Out:
#        pickup_location_id
# count        1.427048e+07
# mean         1.520574e+02
# std          7.159620e+01
# min          1.000000e+00
# 25%          9.200000e+01
# 50%          1.570000e+02
# 75%          2.300000e+02
# max          2.650000e+02

# %% [markdown]
# The following code show the total missing values for each column of uber trips 2015

# %%
print("null values uber trips 2015: \n ")
print(df_uber_trips_2015.isna().sum())
# Out:
# null values uber trips 2015:
#
# pickup_datetime            0
# pickup_location_id         0
# dispatch_base              0
# affiliate_base        162195
# dtype: int64

# %% [markdown]
# OUTLIERS IN UBER TRIPS 2015

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_uber_trips_2015['pickup_location_id'], color='black')
plt.xlabel('pickup_location_id', fontsize=14)
plt.show()

# %% [markdown]
# DATA YELLOW TRIPS

# %%
print(df_yellow_trips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7974059 entries, 0 to 7974058
# Data columns (total 9 columns):
# pickup_datetime      object
# dropoff_datetime     object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count      int64
# trip_distance        float64
# total_amount         float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 547.5+ MB
# None

# %%
print(df_yellow_trips.describe())
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count      7.974059e+06     7.974059e+06       7.974059e+06      7.974059e+06
# mean      -7.244694e+01     3.990894e+01      -7.246507e+01      3.991985e+01
# std        1.052101e+01     5.796364e+00       1.046042e+01      5.763262e+00
# min       -1.800000e+02    -1.800000e+02      -7.364167e+02     -1.800000e+02
# 25%       -7.399203e+01     4.073474e+01      -7.399137e+01      4.073344e+01
# 50%       -7.398172e+01     4.075247e+01      -7.397979e+01      4.075291e+01
# 75%       -7.396661e+01     4.076706e+01      -7.396233e+01      4.076824e+01
# max        1.720110e+02     6.220818e+01       1.720110e+02      4.043000e+02
#
#        passenger_count  trip_distance  total_amount
# count     7.974059e+06   7.974059e+06  7.974059e+06
# mean      1.688382e+00   1.659788e+01  1.560997e+01
# std       1.346068e+00   1.063671e+04  1.347520e+01
# min       0.000000e+00   0.000000e+00 -2.188000e+02
# ...

# %% [markdown]
# The following code show the total missing values for each column of yellow trips

# %%
print("null values yellow trips: \n ")
print(df_yellow_trips.isna().sum())
# Out:
# null values yellow trips:
#
# pickup_datetime      0
# dropoff_datetime     0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# trip_distance        0
# total_amount         0
# dtype: int64

# %% [markdown]
# OUTLIERS IN YELLOW TRIPS

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df_yellow_trips['passenger_count'], color='black')
plt.xlabel('passenger_count', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df_yellow_trips['trip_distance'], color='black')
plt.xlabel('trip_distance', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_yellow_trips['total_amount'], color='black')
plt.xlabel('total_amount', fontsize=14)
plt.show()

# %% [markdown]
# DATA WEATHER

# %%
print(df_weather.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 10 columns):
# date             2190 non-null object
# max_temp         2190 non-null int64
# min_temp         2190 non-null int64
# avg_temp         2190 non-null float64
# precipitation    2190 non-null object
# snowfall         2190 non-null object
# snow_depth       2190 non-null object
# location         2190 non-null object
# latitude         2190 non-null float64
# longitude        2190 non-null float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 171.2+ KB
# None

# %%
print(df_weather.describe())
# Out:
#           max_temp     min_temp     avg_temp     latitude    longitude
# count  2190.000000  2190.000000  2190.000000  2190.000000  2190.000000
# mean     62.706849    48.228311    55.467580    40.731850   -73.876045
# std      18.940456    18.057897    18.343926     0.059712     0.079316
# min      17.000000     2.000000    10.500000    40.647490   -73.974187
# 25%      47.000000    35.000000    41.000000    40.647490   -73.974187
# 50%      65.000000    51.000000    58.000000    40.771133   -73.873966
# 75%      80.000000    64.000000    72.000000    40.776927   -73.779982
# max      97.000000    83.000000    89.000000    40.776927   -73.779982

# %% [markdown]
# The following code show the total missing values for each column of weather

# %%
print("null values weather: \n ")
print(df_weather.isna().sum())
# Out:
# null values weather:
#
# date             0
# max_temp         0
# min_temp         0
# avg_temp         0
# precipitation    0
# snowfall         0
# snow_depth       0
# location         0
# latitude         0
# longitude        0
# dtype: int64

# %% [markdown]
# OUTLIERS WEATHER

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_weather['max_temp'], color='black')
plt.xlabel('max_temp', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_weather['min_temp'], color='black')
plt.xlabel('min_temp', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_weather['avg_temp'], color='black')
plt.xlabel('avg_temp', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x=df_weather['precipitation'], color='black')
plt.xlabel('precipitation', fontsize=14)
plt.show()

# %% [markdown]
# DATA ZONES

# %%
print(df_zones.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 5 columns):
# location_id     263 non-null int64
# borough         263 non-null object
# zone            263 non-null object
# service_zone    263 non-null object
# nta_code        263 non-null object
# dtypes: int64(1), object(4)
# memory usage: 10.4+ KB
# None

# %%
print(df_zones.describe())
# Out:
#        location_id
# count   263.000000
# mean    132.000000
# std      76.065761
# min       1.000000
# 25%      66.500000
# 50%     132.000000
# 75%     197.500000
# max     263.000000

# %% [markdown]
# The following code show the total missing values for each column of zones

# %%
print("null values zones: \n ")
print(df_zones.isna().sum())
# Out:
# null values zones:
#
# location_id     0
# borough         0
# zone            0
# service_zone    0
# nta_code        0
# dtype: int64

# %% [markdown]
# DATA MERGED

# %%
df_demographics_zones=pd.merge(df_demographics,df_zones,on='nta_code')
df_demographics_zones
# Out:
#                                               nta_name      borough_x  \
# 0                              Allerton-Pelham Gardens          Bronx
# 1           Annadale-Huguenot-Prince's Bay-Eltingville  Staten Island
# 2                                        Arden Heights  Staten Island
# 3                                              Astoria         Queens
# 4                                              Astoria         Queens
# 5                                           Auburndale         Queens
# 6                                         Baisley Park         Queens
# 7                                           Bath Beach       Brooklyn
# 8                    Battery Park City-Lower Manhattan      Manhattan
# 9                    Battery Park City-Lower Manhattan      Manhattan
# 10                   Battery Park City-Lower Manhattan      Manhattan
# 11                   Battery Park City-Lower Manhattan      Manhattan
# ...

# %%
df_green_and_yellow_trips_a=pd.merge(df_green_trips_new_2,df_yellow_trips,on='pickup_datetime')
df_green_and_yellow_trips_a
# Out:
#              pickup_datetime   dropoff_datetime_x  pickup_longitude_x  \
# 0        2015-02-01 01:26:45  2015-02-01 01:49:58          -73.953545
# 1        2014-08-29 00:03:16  2014-08-29 00:36:01          -73.993042
# 2        2015-01-21 18:32:22  2015-01-21 18:38:33          -73.927696
# 3        2015-01-21 18:32:22  2015-01-21 18:41:52          -73.963409
# 4        2015-05-19 13:04:33  2015-05-19 13:10:08          -73.803421
# 5        2015-03-12 18:53:58  2015-03-12 18:56:55          -73.957581
# 6        2015-03-31 16:02:29  2015-03-31 16:15:25          -73.962082
# 7        2015-05-26 23:13:37  2015-05-26 23:33:35          -73.943657
# 8        2015-05-15 11:13:49  2015-05-15 11:28:24          -73.869888
# 9        2015-05-15 11:13:49  2015-05-15 11:47:14          -73.804482
# 10       2014-05-19 09:50:37  2014-05-19 09:54:30          -73.950706
# 11       2015-02-02 22:05:42  2015-02-02 22:06:43          -73.950363
# ...

# %%
df_uber2015_and_yellow_trips=pd.merge(df_uber_trips_2015,df_yellow_trips,on='pickup_datetime')
df_uber2015_and_yellow_trips
# Out:
#              pickup_datetime  pickup_location_id dispatch_base affiliate_base  \
# 0        2015-05-17 09:49:00                 229        B02617         B02617
# 1        2015-05-17 09:49:00                 164        B02617         B02617
# 2        2015-05-17 09:49:00                 237        B02617         B02617
# 3        2015-05-17 09:49:00                 142        B02617         B02617
# 4        2015-05-17 09:49:00                 188        B02617         B02617
# 5        2015-05-17 09:49:00                 237        B02617         B02617
# 6        2015-05-17 09:49:00                 224        B02617         B02617
# 7        2015-05-17 09:49:00                 238        B02617         B02617
# 8        2015-05-17 09:49:00                 242        B02617         B02682
# 9        2015-05-17 09:49:00                 209        B02682         B02682
# 10       2015-05-17 09:49:00                  25        B02682         B02682
# ...
